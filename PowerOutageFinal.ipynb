# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# !pip install wwo-hist

# %%
from wwo_hist import retrieve_hist_data

import os

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# %%
#Raw content URL for adult-all.txt
url = "https://raw.githubusercontent.com/hastighsh/Ellehacks_2024/main/power_outages_data_copy.csv"

#Specify the delimiter (assuming it's a tab-separated file)
delimiter = ','

#Read the data into a DataFrame
power_outages_data = pd.read_csv(url, delimiter=delimiter)

#Let's create a backup copy of the dataset
outage_backup = power_outages_data.copy()

# %%
power_outages_data
# Out:
#       Unnamed: 0               Event Description  Year Date Event Began  \
# 0              0  Severe Weather - Thunderstorms  2014        6/30/2014
# 1              1  Severe Weather - Thunderstorms  2014        6/30/2014
# 2              2  Severe Weather - Thunderstorms  2014        6/30/2014
# 3              3    Fuel Supply Emergency - Coal  2014        6/27/2014
# 4              4     Physical Attack - Vandalism  2014        6/24/2014
# ...          ...                             ...   ...              ...
# 1647        1647          Transmission Line Loss  2000        3/18/2000
# 1648        1648                       Vandalism  2000        3/14/2000
# 1649        1649                       Ice Storm  2000        1/29/2000
# 1650        1650                       Ice Storm  2000        1/24/2000
# 1651        1651                       Ice Storm  2000        1/23/2000
#
#      Date of Restoration                               Respondent  \
# 0               7/2/2014                 Exelon Corporation/ComEd
# 1               7/1/2014  Northern Indiana Public Service Company
# 2               7/1/2014                              We Energies
# 3                Unknown                              We Energies
# 4              6/24/2014               Tennessee Valley Authority
# ...                  ...                                      ...
# 1647           3/18/2000                        El Paso Elec. Co.
# 1648                 NaN                           Alliant Energy
# 1649            2/3/2000                           Duke Power Co.
# 1650                 NaN                   Carolina Power & Light
# 1651           1/28/2000                           Duke Power Co.
#
#                               Geographic Areas NERC Region Demand Loss (MW)  \
# 0                                     Illinois         RFC          Unknown
# 1                        North Central Indiana         RFC          Unknown
# 2                         Southeast  Wisconsin         MRO              424
# 3                                    Wisconsin         MRO          Unknown
# 4                         Nashville, Tennessee        SERC          Unknown
# ...                                        ...         ...              ...
# 1647                                     Texas        MAIN              400
# 1648                                     Maine        MAIN              NaN
# 1649                            South Carolina        SERC              300
# 1650  North Carolina & Northern South Carolina        SERC              960
# 1651                            South Carolina        SERC              450
#
#      Number of Customers Affected                          Tags  \
# 0                         420,000  severe weather, thunderstorm
# 1                         127,000  severe weather, thunderstorm
# 2                         120,000  severe weather, thunderstorm
# 3                         Unknown   fuel supply emergency, coal
# 4                         Unknown           vandalism, physical
# ...                           ...                           ...
# 1647                      100,000     transmission interruption
# 1648                          NaN                     vandalism
# 1649                       81,000  severe weather, winter storm
# 1650                      173,000  severe weather, winter storm
# 1651                      133,000  severe weather, winter storm
#
#      Time Event Began Time of Restoration
# 0            20:00:00            18:30:00
# 1            23:20:00            17:00:00
# 2            17:55:00            02:53:00
# 3            13:21:00                 NaN
# 4            14:54:00            14:55:00
# ...               ...                 ...
# 1647         16:00:00            17:10:00
# 1648         21:06:00                 NaN
# 1649         22:00:00            12:00:00
# 1650         19:00:00                 NaN
# 1651         08:00:00            12:00:00
#
# [1652 rows x 13 columns]

# %%
power_outages_data = power_outages_data.drop(["Unnamed: 0", "NERC Region", "Demand Loss (MW)", "Number of Customers Affected"], axis=1)

# %%
# Count missing values in each column
missing_values = power_outages_data.isnull().sum()

print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Event Description       0
# Year                    0
# Date Event Began        0
# Date of Restoration    14
# Respondent              0
# Geographic Areas        1
# Tags                    1
# Time Event Began       12
# Time of Restoration    44
# dtype: int64

# %%
cleaned_power_outages = power_outages_data.dropna()

# %%
cleaned_power_outages
# Out:
#                    Event Description  Year Date Event Began  \
# 0     Severe Weather - Thunderstorms  2014        6/30/2014
# 1     Severe Weather - Thunderstorms  2014        6/30/2014
# 2     Severe Weather - Thunderstorms  2014        6/30/2014
# 4        Physical Attack - Vandalism  2014        6/24/2014
# 5        Physical Attack - Vandalism  2014        6/19/2014
# ...                              ...   ...              ...
# 1642                  Severe Weather  2000         5/2/2000
# 1646          Transmission Line Loss  2000        3/18/2000
# 1647          Transmission Line Loss  2000        3/18/2000
# 1649                       Ice Storm  2000        1/29/2000
# 1651                       Ice Storm  2000        1/23/2000
#
#      Date of Restoration                               Respondent  \
# 0               7/2/2014                 Exelon Corporation/ComEd
# 1               7/1/2014  Northern Indiana Public Service Company
# 2               7/1/2014                              We Energies
# 4              6/24/2014               Tennessee Valley Authority
# 5              6/19/2014               Tennessee Valley Authority
# ...                  ...                                      ...
# 1642            5/2/2000                      Reliant Energy HL&P
# 1646           3/18/2000             Public Service of New Mexico
# 1647           3/18/2000                        El Paso Elec. Co.
# 1649            2/3/2000                           Duke Power Co.
# 1651           1/28/2000                           Duke Power Co.
#
#            Geographic Areas                          Tags Time Event Began  \
# 0                  Illinois  severe weather, thunderstorm         20:00:00
# 1     North Central Indiana  severe weather, thunderstorm         23:20:00
# 2      Southeast  Wisconsin  severe weather, thunderstorm         17:55:00
# 4      Nashville, Tennessee           vandalism, physical         14:54:00
# 5      Nashville, Tennessee           vandalism, physical         08:47:00
# ...                     ...                           ...              ...
# 1642            Houston, TX                severe weather         04:00:00
# 1646             New Mexico     transmission interruption         19:08:00
# 1647                  Texas     transmission interruption         16:00:00
# 1649         South Carolina  severe weather, winter storm         22:00:00
# 1651         South Carolina  severe weather, winter storm         08:00:00
#
#      Time of Restoration
# 0               18:30:00
# 1               17:00:00
# 2               02:53:00
# 4               14:55:00
# 5               08:48:00
# ...                  ...
# 1642            12:00:00
# 1646            19:08:00
# 1647            17:10:00
# 1649            12:00:00
# 1651            12:00:00
#
# [1605 rows x 9 columns]

# %%
city_counts = cleaned_power_outages['Geographic Areas'].value_counts()

# Print the counts for each city
print(city_counts)
# Out:
# Island of Puerto Rico              30
# California                         24
# Texas                              20
# Northern California                20
# Tacoma, Washington                 17
#                                    ..
# Northeast, Illinois                 1
# Jefferson, Oregon                   1
# Fredrickson, Washington             1
# Entire ComEd Territory, Indiana     1
# New Mexico                          1
# Name: Geographic Areas, Length: 985, dtype: int64

# %%
top_20_cities = city_counts.head(20)
print("Top 20 cities:")
print(top_20_cities)
# Out:
# Top 20 cities:
# Island of Puerto Rico                 30
# California                            24
# Texas                                 20
# Northern California                   20
# Tacoma, Washington                    17
# Southeastern Michigan                 14
# Illinois                              12
# New York                              12
# Southern California                   12
# Northern and Central California       10
# Georgia                               10
# Pennsylvania                          10
# Newark, Delaware                      10
# San Francisco Bay Area, California    10
# Northern Illinois                     10
# Alberta, Canada                        9
# Ohio                                   9
# Virginia                               9
# North Carolina                         8
# Michigan                               8
# Name: Geographic Areas, dtype: int64

# %%
# Split the "Event Description" column into two separate columns
cleaned_power_outages[['Category', 'Sub Category']] = cleaned_power_outages['Event Description'].str.split(' - ', 1, expand=True)
cleaned_power_outages.drop('Event Description', axis=1, inplace=True)

# Print the first few rows
cleaned_power_outages
# Out:
# C:\Users\Heliiix\AppData\Local\Temp\ipykernel_9180\895595742.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   cleaned_power_outages[['Category', 'Sub Category']] = cleaned_power_outages['Event Description'].str.split(' - ', 1, expand=True)
# C:\Users\Heliiix\AppData\Local\Temp\ipykernel_9180\895595742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_power_outages[['Category', 'Sub Category']] = cleaned_power_outages['Event Description'].str.split(' - ', 1, expand=True)
# C:\Users\Heliiix\AppData\Local\Temp\ipykernel_9180\895595742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_power_outages[['Category', 'Sub Category']] = cleaned_power_outages['Event Description'].str.split(' - ', 1, expand=True)
# C:\Users\Heliiix\AppData\Local\Temp\ipykernel_9180\895595742.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_power_outages.drop('Event Description', axis=1, inplace=True)
#       Year Date Event Began Date of Restoration  \
# 0     2014        6/30/2014            7/2/2014
# 1     2014        6/30/2014            7/1/2014
# 2     2014        6/30/2014            7/1/2014
# 4     2014        6/24/2014           6/24/2014
# 5     2014        6/19/2014           6/19/2014
# ...    ...              ...                 ...
# 1642  2000         5/2/2000            5/2/2000
# 1646  2000        3/18/2000           3/18/2000
# 1647  2000        3/18/2000           3/18/2000
# 1649  2000        1/29/2000            2/3/2000
# 1651  2000        1/23/2000           1/28/2000
#
#                                    Respondent       Geographic Areas  \
# 0                    Exelon Corporation/ComEd               Illinois
# 1     Northern Indiana Public Service Company  North Central Indiana
# 2                                 We Energies   Southeast  Wisconsin
# 4                  Tennessee Valley Authority   Nashville, Tennessee
# 5                  Tennessee Valley Authority   Nashville, Tennessee
# ...                                       ...                    ...
# 1642                      Reliant Energy HL&P            Houston, TX
# 1646             Public Service of New Mexico             New Mexico
# 1647                        El Paso Elec. Co.                  Texas
# 1649                           Duke Power Co.         South Carolina
# 1651                           Duke Power Co.         South Carolina
#
#                               Tags Time Event Began Time of Restoration  \
# 0     severe weather, thunderstorm         20:00:00            18:30:00
# 1     severe weather, thunderstorm         23:20:00            17:00:00
# 2     severe weather, thunderstorm         17:55:00            02:53:00
# 4              vandalism, physical         14:54:00            14:55:00
# 5              vandalism, physical         08:47:00            08:48:00
# ...                            ...              ...                 ...
# 1642                severe weather         04:00:00            12:00:00
# 1646     transmission interruption         19:08:00            19:08:00
# 1647     transmission interruption         16:00:00            17:10:00
# 1649  severe weather, winter storm         22:00:00            12:00:00
# 1651  severe weather, winter storm         08:00:00            12:00:00
#
#                     Category   Sub Category
# 0             Severe Weather  Thunderstorms
# 1             Severe Weather  Thunderstorms
# 2             Severe Weather  Thunderstorms
# 4            Physical Attack      Vandalism
# 5            Physical Attack      Vandalism
# ...                      ...            ...
# 1642          Severe Weather           None
# 1646  Transmission Line Loss           None
# 1647  Transmission Line Loss           None
# 1649               Ice Storm           None
# 1651               Ice Storm           None
#
# [1605 rows x 10 columns]

# %%
cleaned_power_outages.drop('Year', axis=1, inplace=True)
cleaned_power_outages
# Out:
# C:\Users\Heliiix\AppData\Local\Temp\ipykernel_9180\937145297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_power_outages.drop('Year', axis=1, inplace=True)
#      Date Event Began Date of Restoration  \
# 0           6/30/2014            7/2/2014
# 1           6/30/2014            7/1/2014
# 2           6/30/2014            7/1/2014
# 4           6/24/2014           6/24/2014
# 5           6/19/2014           6/19/2014
# ...               ...                 ...
# 1642         5/2/2000            5/2/2000
# 1646        3/18/2000           3/18/2000
# 1647        3/18/2000           3/18/2000
# 1649        1/29/2000            2/3/2000
# 1651        1/23/2000           1/28/2000
#
#                                    Respondent       Geographic Areas  \
# 0                    Exelon Corporation/ComEd               Illinois
# 1     Northern Indiana Public Service Company  North Central Indiana
# 2                                 We Energies   Southeast  Wisconsin
# 4                  Tennessee Valley Authority   Nashville, Tennessee
# 5                  Tennessee Valley Authority   Nashville, Tennessee
# ...                                       ...                    ...
# 1642                      Reliant Energy HL&P            Houston, TX
# 1646             Public Service of New Mexico             New Mexico
# 1647                        El Paso Elec. Co.                  Texas
# 1649                           Duke Power Co.         South Carolina
# 1651                           Duke Power Co.         South Carolina
#
#                               Tags Time Event Began Time of Restoration  \
# 0     severe weather, thunderstorm         20:00:00            18:30:00
# 1     severe weather, thunderstorm         23:20:00            17:00:00
# 2     severe weather, thunderstorm         17:55:00            02:53:00
# 4              vandalism, physical         14:54:00            14:55:00
# 5              vandalism, physical         08:47:00            08:48:00
# ...                            ...              ...                 ...
# 1642                severe weather         04:00:00            12:00:00
# 1646     transmission interruption         19:08:00            19:08:00
# 1647     transmission interruption         16:00:00            17:10:00
# 1649  severe weather, winter storm         22:00:00            12:00:00
# 1651  severe weather, winter storm         08:00:00            12:00:00
#
#                     Category   Sub Category
# 0             Severe Weather  Thunderstorms
# 1             Severe Weather  Thunderstorms
# 2             Severe Weather  Thunderstorms
# 4            Physical Attack      Vandalism
# 5            Physical Attack      Vandalism
# ...                      ...            ...
# 1642          Severe Weather           None
# 1646  Transmission Line Loss           None
# 1647  Transmission Line Loss           None
# 1649               Ice Storm           None
# 1651               Ice Storm           None
#
# [1605 rows x 9 columns]

# %%
# Get the top 20 cities
top_20_cities = city_counts.head(20).index

# Create a boolean mask indicating whether each row's city is in the top 20 cities
mask = cleaned_power_outages['Geographic Areas'].isin(top_20_cities)

# Filter the DataFrame to keep only the rows with cities in the top 20
df_top_20 = cleaned_power_outages[mask]

# Print the resulting DataFrame
print("DataFrame with rows for the top 20 cities only:")
df_top_20
# Out:
# DataFrame with rows for the top 20 cities only:
#      Date Event Began Date of Restoration  \
# 0           6/30/2014            7/2/2014
# 13           6/9/2014            6/9/2014
# 18           6/3/2014            6/3/2014
# 19           6/3/2014            6/3/2014
# 22          5/23/2014           5/25/2014
# ...               ...                 ...
# 1628         8/6/2000            8/7/2000
# 1636        5/25/2000            6/2/2000
# 1637        5/24/2000           5/25/2000
# 1640         5/9/2000            5/9/2000
# 1647        3/18/2000           3/18/2000
#
#                                Respondent Geographic Areas  \
# 0                Exelon Corporation/ComEd         Illinois
# 13                       Peak Reliability  Alberta, Canada
# 18                       Peak Reliability  Alberta, Canada
# 19         Lower Colorado River Authority            Texas
# 22                   Duke Energy Progress   North Carolina
# ...                                   ...              ...
# 1628                  Commonwealth Edison         Illinois
# 1636                           Duke Power   North Carolina
# 1637                              Entergy            Texas
# 1640  Consolidated Edison Co. of New York         New York
# 1647                    El Paso Elec. Co.            Texas
#
#                               Tags Time Event Began Time of Restoration  \
# 0     severe weather, thunderstorm         20:00:00            18:30:00
# 13                       islanding         11:07:00            11:30:00
# 18                       islanding         15:32:00            15:59:00
# 19             vandalism, physical         01:38:00            01:43:00
# 22             vandalism, physical         15:00:00            19:00:00
# ...                            ...              ...                 ...
# 1628                severe weather         16:00:00            12:00:00
# 1636                severe weather         10:00:00            06:00:00
# 1637             voltage reduction         10:15:00            22:14:00
# 1640                 load shedding         11:39:00            23:00:00
# 1647     transmission interruption         16:00:00            17:10:00
#
#                          Category   Sub Category
# 0                  Severe Weather  Thunderstorms
# 13    Electrical System Islanding           None
# 18    Electrical System Islanding           None
# 19                Physical Attack      Vandalism
# 22                Physical Attack      Vandalism
# ...                           ...            ...
# 1628               Severe Weather           None
# 1636               Severe Weather           None
# 1637           Voltage Elec Usage           None
# 1640          Energy Conservation           None
# 1647       Transmission Line Loss           None
#
# [264 rows x 9 columns]

# %%
# Filter rows containing 'weather' in the 'Category' column
df_top_20 = df_top_20[df_top_20['Category'].str.contains('weather', case=False, na=False)]

# Reset index if needed
df_top_20.reset_index(drop=True, inplace=True)

# %%
df_top_20
# Out:
#    Date Event Began Date of Restoration  \
# 0         6/30/2014            7/2/2014
# 1         4/12/2014           4/15/2014
# 2         3/12/2014           3/13/2014
# 3         2/12/2014           2/15/2014
# 4          2/5/2014            2/9/2014
# 5          2/5/2014            2/5/2014
# 6          1/7/2014            1/8/2014
# 7          1/7/2014            1/7/2014
# 8          1/7/2014            1/7/2014
# 9          1/6/2014            1/6/2014
# 10         1/6/2014            1/6/2014
# 11         1/6/2014            1/7/2014
# 12       12/22/2013          12/25/2013
# 13       11/21/2013          11/22/2013
# 14       11/17/2013          11/20/2013
# 15        9/11/2013           9/15/2013
# 16        7/19/2013           7/21/2013
# 17        7/19/2013           7/20/2013
# 18        6/24/2013           6/25/2013
# 19        1/20/2013           1/23/2013
# 20        12/2/2012           12/4/2012
# 21       10/29/2012          10/30/2012
# 22       10/29/2012           11/4/2012
# 23         9/8/2012            9/9/2012
# 24        7/24/2012           7/24/2012
# 25        7/18/2012           7/19/2012
# 26         7/1/2012            7/3/2012
# 27        6/29/2012            7/4/2012
# 28        12/1/2011           12/7/2011
# 29        12/1/2011           12/2/2011
# 30       10/29/2011           11/7/2011
# 31       10/29/2011           11/7/2011
# 32        8/28/2011           8/28/2011
# 33        8/28/2011            9/3/2011
# 34        8/27/2011           8/29/2011
# 35        8/26/2011           8/28/2011
# 36        8/20/2011           8/23/2011
# 37        7/23/2011           7/24/2011
# 38        7/11/2011           7/11/2011
# 39        7/11/2011           7/11/2011
# 40         7/4/2011            7/4/2011
# 41        6/30/2011            7/1/2011
# 42         6/7/2011            6/8/2011
# 43        4/19/2011           4/19/2011
# 44        2/25/2011           2/25/2011
# 45         2/9/2011           2/10/2011
# 46       12/12/2010          12/15/2010
# 47        8/19/2010           8/23/2010
# 48        8/11/2010           8/11/2010
# 49        7/23/2010           7/26/2010
# 50        7/15/2010           7/19/2010
# 51       12/10/2009          12/12/2009
# 52        12/9/2009          12/10/2009
# 53       12/26/2006          12/31/2006
# 54       11/15/2006          11/15/2006
# 55        8/18/2000           8/20/2000
# 56         8/9/2000            8/7/2000
# 57         8/6/2000            8/7/2000
# 58        5/25/2000            6/2/2000
#
#                                            Respondent       Geographic Areas  \
# 0                            Exelon Corporation/ComEd               Illinois
# 1                              Detroit Edison Company               Michigan
# 2                               Duke Energy Carolinas         North Carolina
# 3                                Duke Energy Progress         North Carolina
# 4                            FirstEnergy Corp: Met-Ed           Pennsylvania
# 5                             Exelon Corporation/PECO           Pennsylvania
# 6                                Duke Energy Progress         North Carolina
# 7                                Duke Energy Progress         North Carolina
# 8                                 PJM Interconnection           Pennsylvania
# 9                                  UGI Utilities, Inc           Pennsylvania
# 10                        PPL Electric Utilities Corp           Pennsylvania
# 11                                              ERCOT                  Texas
# 12                                  Detroit Edison Co               Michigan
# 13                          Pacific Gas & Electric Co    Northern California
# 14                                  Detroit Edison Co               Michigan
# 15                                  Detroit Edison Co  Southeastern Michigan
# 16  Niagara Mohawk Power Corporation (dba National...               New York
# 17                                  Detroit Edison Co               Michigan
# 18                           Exelon Corporation/ComEd               Illinois
# 19                                  Detroit Edison Co  Southeastern Michigan
# 20                          Pacific Gas & Electric Co    Northern California
# 21                            Dominion Virginia Power               Virginia
# 22                              Iberdrola USA (NYSEG)               New York
# 23                            Dominion Virginia Power               Virginia
# 24                           Exelon Corporation/ComEd      Northern Illinois
# 25                           Exelon Corporation/ComEd      Northern Illinois
# 26                           Exelon Corporation/ComEd               Illinois
# 27                                           Dominion               Virginia
# 28                   Southern California Edison (SCE)    Southern California
# 29                           Pacific Gas and Electric    Northern California
# 30                        Metropolitan Edison Company           Pennsylvania
# 31                                     Potomac Edison           Pennsylvania
# 32                Orange and Rockland Utilities, Inc.               New York
# 33          New York State Electric & Gas Corporation               New York
# 34                          Exelon Corporation / PECO           Pennsylvania
# 35      FirstEnergy Corp: Metropolitan Edison Company           Pennsylvania
# 36           Detroit Edison, Subsidiary of DTE Energy  Southeastern Michigan
# 37                           Exelon Corporation/ComEd               Illinois
# 38           Detroit Edison, Subsidiary of DTE Energy               Michigan
# 39                           Exelon Corporation/ComEd               Illinois
# 40                            Dominion Virginia Power               Virginia
# 41                           Exelon Corporation/ComEd               Illinois
# 42                            American Electric Power                   Ohio
# 43                                    Ameren Illinois               Illinois
# 44                          Dominion - Virginia Power               Virginia
# 45                                          ERCOT ISO                  Texas
# 46                                     Detroit Edison  Southeastern Michigan
# 47                                     Detroit Edison  Southeastern Michigan
# 48                            American Electric Power                   Ohio
# 49                                     Detroit Edison  Southeastern Michigan
# 50                                     Detroit Edison  Southeastern Michigan
# 51                                     Detroit Edison               Michigan
# 52                            American Electric Power                   Ohio
# 53                   Pacific Gas and Electric Company    Northern California
# 54                                   Southern Company                Georgia
# 55                                         Duke Power         North Carolina
# 56                                       Cinergy Corp                   Ohio
# 57                                Commonwealth Edison               Illinois
# 58                                         Duke Power         North Carolina
#
#                                         Tags Time Event Began  \
# 0               severe weather, thunderstorm         20:00:00
# 1                             severe weather         20:00:00
# 2                       severe weather, wind         19:35:00
# 3               severe weather, winter storm         12:10:00
# 4               severe weather, winter storm         01:00:00
# 5               severe weather, winter storm         05:00:00
# 6                       severe weather, cold         16:15:00
# 7        severe weather, cold, public appeal         07:58:00
# 8                       severe weather, cold         06:18:00
# 9                       severe weather, cold         19:50:00
# 10                      severe weather, cold         19:50:00
# 11                      severe weather, cold         07:01:00
# 12              severe weather, winter storm         06:30:00
# 13                      severe weather, wind         19:45:00
# 14              severe weather, winter storm         07:00:00
# 15              severe weather, thunderstorm         16:00:00
# 16              severe weather, thunderstorm         22:30:00
# 17              severe weather, thunderstorm         18:00:00
# 18              severe weather, thunderstorm         19:30:00
# 19                      severe weather, wind         03:30:00
# 20              severe weather, winter storm         05:20:00
# 21  severe weather, hurricane/tropical storm         18:12:00
# 22  severe weather, hurricane/tropical storm         18:48:00
# 23              severe weather, thunderstorm         15:53:00
# 24              severe weather, thunderstorm         07:30:00
# 25              severe weather, thunderstorm         23:00:00
# 26              severe weather, thunderstorm         13:00:00
# 27              severe weather, thunderstorm         22:29:00
# 28                            severe weather         00:45:00
# 29                            severe weather         03:29:00
# 30                            severe weather         08:59:00
# 31                            severe weather         08:59:00
# 32                            severe weather         12:30:00
# 33                            severe weather         07:00:00
# 34                            severe weather         22:00:00
# 35                            severe weather         00:30:00
# 36                            severe weather         17:42:00
# 37                            severe weather         02:30:00
# 38                            severe weather         09:00:00
# 39                            severe weather         09:00:00
# 40                            severe weather         18:00:00
# 41                            severe weather         22:30:00
# 42                            severe weather         14:00:00
# 43                            severe weather         20:00:00
# 44                            severe weather         15:20:00
# 45                      severe weather, cold         16:30:00
# 46                            severe weather         16:30:00
# 47                            severe weather         18:00:00
# 48                            severe weather         15:21:00
# 49                            severe weather         19:30:00
# 50                            severe weather         19:00:00
# 51                            severe weather         17:45:00
# 52                            severe weather         13:37:00
# 53                            severe weather         00:01:00
# 54                            severe weather         15:00:00
# 55                            severe weather         18:30:00
# 56                            severe weather         18:30:00
# 57                            severe weather         16:00:00
# 58                            severe weather         10:00:00
#
#    Time of Restoration                                           Category  \
# 0             18:30:00                                     Severe Weather
# 1             19:30:00                                     Severe Weather
# 2             12:00:00                                     Severe Weather
# 3             15:20:00                                     Severe Weather
# 4             20:40:00                                     Severe Weather
# 5             05:01:00                                     Severe Weather
# 6             13:20:00                Public Appeal due to Severe Weather
# 7             11:00:00  Voltage Reduction; Public Appeal due to Severe...
# 8             06:19:00                                     Severe Weather
# 9             20:49:00            Voltage Reduction due to Severe Weather
# 10            20:44:00            Voltage Reduction due to Severe Weather
# 11            09:00:00                Public Appeal due to Severe Weather
# 12            05:12:00                                     Severe Weather
# 13            03:20:00                                     Severe Weather
# 14            18:54:00                                     Severe Weather
# 15            16:00:00                                     Severe Weather
# 16            20:00:00                                     Severe Weather
# 17            09:00:00                                     Severe Weather
# 18            17:46:00                                     Severe Weather
# 19            06:15:00                                     Severe Weather
# 20            09:00:00                                     Severe Weather
# 21            19:35:00                                     Severe Weather
# 22            11:36:00                                     Severe Weather
# 23            19:46:00                                     Severe Weather
# 24            22:00:00                                     Severe Weather
# 25            06:00:00                                     Severe Weather
# 26            15:00:00                                     Severe Weather
# 27            15:36:00                                     Severe Weather
# 28            21:00:00                                     Severe Weather
# 29            13:05:00                                     Severe Weather
# 30            19:58:00                                     Severe Weather
# 31            15:00:00                                     Severe Weather
# 32            12:31:00                                     Severe Weather
# 33            00:01:00                                     Severe Weather
# 34            22:00:00                                     Severe Weather
# 35            00:30:00                                     Severe Weather
# 36            20:00:00                                     Severe Weather
# 37            09:00:00                                     Severe Weather
# 38            10:25:00                                     Severe Weather
# 39            09:00:00                                     Severe Weather
# 40            21:00:00                                     Severe Weather
# 41            17:00:00                                     Severe Weather
# 42            06:00:00                                     Severe Weather
# 43            22:00:00                                     Severe Weather
# 44            18:00:00                                     Severe Weather
# 45            12:33:00                                 Cold Weather Event
# 46            14:00:00                                     Severe Weather
# 47            15:30:00                                     Severe Weather
# 48            12:12:00                                     Severe Weather
# 49            18:30:00                                     Severe Weather
# 50            23:30:00                                     Severe Weather
# 51            08:00:00                                     Severe Weather
# 52            06:30:00                                     Severe Weather
# 53            09:13:00                                     Severe Weather
# 54            17:00:00                                     Severe Weather
# 55            12:00:00                                     Severe Weather
# 56            23:59:00                                     Severe Weather
# 57            12:00:00                                     Severe Weather
# 58            06:00:00                                     Severe Weather
#
#           Sub Category
# 0        Thunderstorms
# 1                 None
# 2           High Winds
# 3             Snow/Ice
# 4             Snow/Ice
# 5             Snow/Ice
# 6                 Cold
# 7                 Cold
# 8                 Cold
# 9                 Cold
# 10                Cold
# 11                Cold
# 12            Ice/Snow
# 13          Wind Storm
# 14  Ice and Snow Storm
# 15       Thunderstorms
# 16       Thunderstorms
# 17       Thunderstorms
# 18       Thunderstorms
# 19          Wind Storm
# 20        Winter Storm
# 21     Hurricane Sandy
# 22     Hurricane Sandy
# 23       Thunderstorms
# 24       Thunderstorms
# 25       Thunderstorms
# 26       Thunderstorms
# 27       Thunderstorms
# 28                None
# 29                None
# 30                None
# 31                None
# 32                None
# 33                None
# 34                None
# 35                None
# 36                None
# 37                None
# 38                None
# 39                None
# 40                None
# 41                None
# 42                None
# 43                None
# 44                None
# 45                None
# 46                None
# 47                None
# 48                None
# 49                None
# 50                None
# 51                None
# 52                None
# 53                None
# 54                None
# 55                None
# 56                None
# 57                None
# 58                None

# %%
df_top_20.to_csv("PowerOuta.csv", index=False)
